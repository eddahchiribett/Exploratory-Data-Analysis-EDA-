# %% [markdown]
# <a href="https://colab.research.google.com/github/eddahchiribett/Exploratory-Data-Analysis-EDA-/blob/main/Exploratory_Data_Analysis(EDA)_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.mosaicplot import mosaic

# %%
#Load the dataset
df = pd.read_csv('/content/nhanes_reduced .csv')
age_directChol = df[['Age', 'DirectChol']]

# %%
# Filter the data for ages
filtered_data =df[df['Age'] >40]
#Scatter plot using the filtered data
plt.scatter(filtered_data['Age'], filtered_data['DirectChol'], color = 'blue')

#Adding titles and labels
plt.title('Scatter Plot of Age vs Direct Cholesterol level (Ages> 40)')
plt.xlabel('Age (years)')
plt.ylabel('Direct Cholesterol level (mg/dL)')
# Out:
# Text(0, 0.5, 'Direct Cholesterol level (mg/dL)')

# %%
#Scatter plot analyzing the relationship between BMI and physical level
plt.scatter(filtered_data['BMI'], filtered_data['PhysActiveDays'], color = 'blue')

#Adding titles and labels
plt.title('Scatter Plot of BMI vs PhysActiveDays)')
plt.xlabel('BMI)')
plt.ylabel('PhysActiveDays)')
# Out:
# Text(0, 0.5, 'PhysActiveDays)')

# %%
#Load the dataset
df = pd.read_csv('/content/nhanes_reduced .csv')
df['Work'] = df['Work'].astype('category')

work_categories = data['Work'].cat.categories
fig, ax = plt.subplots(nrows= len(work_categories),ncols =1, figsize=(10, 15), sharex=True)
for ax, category in zip(axes, work_categories) :
    sns.histplot(data[data['Work'] == category]['BMI'], bins = 20,ax=ax)
    ax.set_title(f'Distribution of BMI for {category}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-70d4fac7545e> in <cell line: 7>()
#       5 work_categories = data['Work'].cat.categories
#       6 fig, ax = plt.subplots(nrows= len(work_categories),ncols =1, figsize=(10, 15), sharex=True)
# ----> 7 for ax, category in zip(axes, work_categories) :
#       8     sns.histplot(data[data['Work'] == category]['BMI'], bins = 20,ax=ax)
#       9     ax.set_title(f'Distribution of BMI for {category}')
#
# NameError: name 'axes' is not defined

# %%
#Boxplot of BMI by Household Income
sns.boxplot(x='HHIncome', y='BMI', data =data)
plt.xticks (rotation = 45)
plt.title('Boxplot of BMI by Household Income')
plt.show()

# %%
#Boxplot of BMI by Gender
sns.boxplot(x='Gender', y='BMI', data =data)
plt.xticks (rotation = 45)
plt.title('Boxplot of BMI by Gender')
plt.show()

# %%
#Boxplot of Gender by DirectChol
sns.boxplot(x='Gender', y='DirectChol', data =data)
plt.xticks (rotation = 45)
plt.title('Boxplot of Gender by DirectChol')
plt.show()

# %%
#Density plot
plt.figure(figsize=(10, 6))
sns.kdeplot(data=data, x='BMI', hue='Work', fill=True)
multiple = 'stack'
plt.title('Density Plot of BMI by Work')
plt.xlabel('BMI')
plt.ylabel('Density')
plt.show()

# %%
df = data['BMI']
log_df = np.log(df)
plt.figure(figsize=(10, 6))
plt.plot(df,label='Original Data', marker ='o', linestyle='-', color = 'purple')
plt.plot(log_df, label='Log Transformed Data', marker ='o', linestyle='-', color = 'red' )

multiple = 'stack'
plt.title('Original vs Log Tansformed Data')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()
